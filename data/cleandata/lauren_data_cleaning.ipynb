# %% [markdown]
# ### 1. Convert all xlsx to csv
# Background:
# - Downloaded all datasets related to Passaic River sampling from https://sharepoint.ourpassaic.org/SitePages/Passaic%20River%20Datasets to "xlsx_to_convert" directory. Included: sediment, water column, biota sampling. We will need to review the datasets to determine if they arre alike enough to analyze using the same comparisons.
# - Excluded all datasets related to Newark Bay (OU3) because Newark Bay is outside our geographic scope.
# - Excluded all Bathymetry (mapping the bottom of the river) datasets because we aren't running an analysis on the physical features or water flow of the River.
# - Added all Microsoft Access datasets to a separate directory ("access_to_convert") because those will need a separate conversion process.
#
#
# Now attempting to add a function to open the xlsx datasets from "xlsx_to_convert" directory and save as csv to the "rawdata" directory
# -LK 4/2/2022 at 8am

# %%
import pandas as pd
from pathlib import Path
import numpy as np
import os
import requests
from dotenv import load_dotenv

# %%
def convert_xlsx_to_csv(filename):
    filepath = Path(f'../rawdata/xlsx_to_convert/{filename}')
    csv_data = pd.read_excel(filepath)
    new_filename = filepath.stem
    return csv_data.to_csv(f'../rawdata/{new_filename}.csv')

# %%
# Testing - it works!
# convert_xlsx_to_csv("1999 Late Summer-Early Fall ESP Sampling.xlsx")

# %%
# Now I want to see if we can loop over this folder and convert all of them at once.
xlsx_directory = '../rawdata/xlsx_to_convert'
for filename in os.listdir(xlsx_directory):
    if filename.endswith('.xls'):
        print(filename)
# Out:
# 2013_EPA-DESA_Post_Hurricane_Sandy_Grab.xls
# 2016_CPG_RM10_9_RA_SPME-Cap_Monitor.xls
# 2012_LBG_Newark_Bay_SedFlume_Atterberg.xls

# %%
# I'm re-writing the function to include the for loop inside
def convert_xlsx_to_csv(xlsx_directory):
    for filename in os.listdir(xlsx_directory):
        if filename.endswith('.xlsx'):
            filepath = Path(f'../rawdata/xlsx_to_convert/{filename}')
            csv_data = pd.read_excel(filepath)
            new_filename = filepath.stem
            csv_data.to_csv(f'../rawdata/{new_filename}.csv')
        else:
            pass

# %%
xlsx_directory = '../rawdata/xlsx_to_convert'
# convert_xlsx_to_csv(xlsx_directory)

# %% [markdown]
# ### 2. Narrow down the columns in our csvs to just the columns we want
# Background:
# - In class on 4/2/22 we reviewed the original datasets in excel and identified all columns we want to include in our analysis.
# - The columns are:
# ['LOC_NAME',
# 'SAMPLE_DATE',
# 'TASK_CODE',
# 'ANALYTIC_METHOD',
# 'CAS_RN',
# 'CHEMICAL_NAME',
# 'REPORT_RESULT_VALUE',
# 'REPORT_RESULT_UNIT',
# 'REPORT_RESULT_LIMIT',
# 'DETECT_FLAG',
# 'REPORTABLE_RESULT',
# 'LONGITUDE',
# 'LATITUDE']
# Now we want to write a function that slices the datasets into just those columns. Potential issues are:
# - Different column names

# %%
# Write function to open csvs
def open_raw_csv(data_directory):
    for filename in os.listdir(data_directory):
        if filename.endswith('.csv'):
            filepath = Path(f'../rawdata/{filename}')
            csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
            our_columns = ['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']
            check = all(item in csv_data.columns for item in our_columns)
            if check is True:
                clean_data = csv_data[['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']]
                new_filename = filepath.stem
                clean_data.to_csv(f'../cleandata/{new_filename}.csv')

# %%
raw_data_dir = '../rawdata'
for filename in os.listdir(raw_data_dir):
        if filename.endswith('.csv'):
            filepath = Path(f'../rawdata/{filename}')
            csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
            csv_data.columns = [col_name.upper() for col_name in csv_data.columns]
            upper_columns = ['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']
            check = all(item in csv_data.columns for item in upper_columns)
            if check is True:
                clean_data = csv_data[upper_columns]
                new_filename = filepath.stem
                clean_data.to_csv(f'../cleandata/{new_filename}.csv')
# Out:
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/2918624506.py:5: DtypeWarning: Columns (25,26,33,51,52,53,74,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/2918624506.py:5: DtypeWarning: Columns (68) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/2918624506.py:5: DtypeWarning: Columns (18,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/2918624506.py:5: DtypeWarning: Columns (14,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/2918624506.py:5: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/2918624506.py:5: DtypeWarning: Columns (22,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)

# %%
for filename in os.listdir(raw_data_dir):
    if filename.endswith('.csv'):
        print(filename)
# Out:
# 1999 Late Summer-Early Fall ESP Sampling.csv
# 2015 ERT RM10.9 Suface Sediment Sampling.csv
# 1990 Surficial Sediment Investigation.csv
# 2010 CPG LPR-NB PWCM Field Measurements.csv
# 2012 CPG Tissue Survey Above Dundee Dam.csv
# 2018-2019_Diamond-Alkali_OU2_EPA-PDI-Split-samples.csv
# 2012 CPG Benthic Sediment Above Dundee Dam.csv
# 1995-96 Passaic Study RI_FS Sed Mobility EPA.csv
# 2018-2019_OU2_PDI_Treatability Study_20210924.csv
# 1981-2014_RPI(Bopp)SED-SUS_Matter.csv
# 1999-2000 Minish Park Monitoring Program.csv
# 2019_OU2_PDI_Porewater_Passive_Sampler_20210924.csv
# 2001 Supplemental ESP Biota Sampling.csv
# 1995 USACE Minish Park Investigation.csv
# 2013_EPA-DESA_Post_Hurricane_Sandy_Grab.csv
# 2010 CPG LPR-NB PWCM Sample Dataset.csv
# 1997 Outfall Sampling Program.csv
# 2000 Spring ESP Sampling Program.csv
# 1991-1993 Core Sediment Investigations.csv
# 1995 Sediment Grab Sampling Program.csv
# 2012 OU3 NBSA SedFlume Atterberg Limits.csv
# 2016_CPG_RM10_9_RA_SPME-Cap_Monitor.csv
# 2012_LBG_Newark_Bay_SedFlume_Atterberg.csv
# 1999 Sediment Sampling Program.csv
# 2004 EarthTech SED Coring Pilot Project.csv

# %%
filepath = '/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/rawdata/2018-2019_OU2_PDI_Treatability Study_20210924.csv'
csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
clean_data = csv_data[['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']]
clean_data.head()
# Out:
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/1946028009.py:2: DtypeWarning: Columns (14,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
#   LOC_NAME          SAMPLE_DATE                             TASK_CODE  \
# 0   RM 2.9  2018-11-18 11:40:00  2018-2019 OU2 PDI Treatability Study
# 1   RM 2.9  2018-11-18 11:40:00  2018-2019 OU2 PDI Treatability Study
# 2   RM 2.9  2018-11-18 11:40:00  2018-2019 OU2 PDI Treatability Study
# 3   RM 2.9  2018-11-18 11:40:00  2018-2019 OU2 PDI Treatability Study
# 4   RM 2.9  2018-11-18 11:40:00  2018-2019 OU2 PDI Treatability Study
#
#   ANALYTIC_METHOD         CAS_RN  \
# 0          E1668A  WHOTOTTEQ(H)1
# 1          E1668A  WHOTOTTEQ(H)0
# 2          E1668A  WHOTOTTEQ(H)5
# 3          E1668A  WHOTOTTEQ(F)5
# 4          E1668A  WHOTOTTEQ(F)1
#
#                                     CHEMICAL_NAME  REPORT_RESULT_VALUE  \
# 0    Total WHO PCB/Dioxin TEQ(Human/Mammal)(ND=1)                304.0
# 1    Total WHO PCB/Dioxin TEQ(Human/Mammal)(ND=0)                304.0
# 2  Total WHO PCB/Dioxin TEQ(Human/Mammal)(ND=0.5)                304.0
# 3          Total WHO PCB/Dioxin TEQ(Fish)(ND=0.5)                279.0
# 4            Total WHO PCB/Dioxin TEQ(Fish)(ND=1)                280.0
#
#   REPORT_RESULT_UNIT  REPORT_RESULT_LIMIT DETECT_FLAG REPORTABLE_RESULT  \
# 0               pg/g                6.340           Y               Yes
# 1               pg/g                6.340           Y               Yes
# 2               pg/g                6.340           Y               Yes
# 3               pg/g                0.596           Y               Yes
# 4               pg/g                0.596           Y               Yes
#
#    LONGITUDE   LATITUDE
# 0  -74.12643  40.742445
# 1  -74.12643  40.742445
# 2  -74.12643  40.742445
# 3  -74.12643  40.742445
# 4  -74.12643  40.742445

# %% [markdown]
# def open_one_csv(filename):
#     for filename in os.listdir(data_directory):
#         if filename.endswith('.csv'):
#             filepath = Path(f'../rawdata/{filename}')
#             csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)

# %%
# Use "Column Selector" for loop to pare down large csv datasets
toobig_data_dir = '/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/rawdata/too_big'
for filename in os.listdir(toobig_data_dir):
    if filename.endswith('.csv'):
        filepath = Path(f'/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/rawdata/too_big/{filename}')
        csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
        csv_data.columns = [col_name.upper() for col_name in csv_data.columns]
        upper_columns = ['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']
        check = all(item in csv_data.columns for item in upper_columns)
            if check is True:
                clean_data = csv_data[upper_columns]
                new_filename = filepath.stem
                clean_data.to_csv(f'/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/cleandata/{new_filename}.csv')
# Out:
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/3760036492.py:6: DtypeWarning: Columns (18,19,26,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/3760036492.py:6: DtypeWarning: Columns (13,20,21,22,30,34,35,66,72,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/3760036492.py:6: DtypeWarning: Columns (18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/3760036492.py:6: DtypeWarning: Columns (18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/3760036492.py:6: DtypeWarning: Columns (72) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/3760036492.py:6: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
# /var/folders/d9/6r5nm8y56sbbg2kbt5s3pxhr0000gn/T/ipykernel_56994/3760036492.py:6: DtypeWarning: Columns (22,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)

# %%
# There are 5 datasets that still need to be pared down because they are still over 50mb:
# 2017-2019_OU2_PDI_Sediment_PCB_20210924.csv
# 2018_GSH_LPR_8-3mile_data.csv
# 2017_GSH_LPR_8-3mile_data.csv
# 2008 CPG Low Res Coring Dataset.csv
# 2017-2019_OU2_PDI_Sediment_NON_PCB_20210924.csv

# %%
filepath = Path(f'/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/cleandata/2017-2019_OU2_PDI_Sediment_PCB_20210924.csv')
big_df = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)

big_df.iloc[:100000].to_csv('temp.csv')
os.path.getsize('2017-2019_OU2_PDI_Sediment_PCB_20210924.csv')
# Out:
# 145270923

# %%
17911712
145270923
50000000

# %%
rows_max = int(5e5)
filepath = Path(f'../rawdata/too_big/{filename}')
row_from = 0
row_to = rows_max
file_n = 1

while True:
    fn_i = 'big_%s.csv' % str(file_n).zfill(3)
    big_df.iloc[row_from:row_to].to_csv(fn_i)

    if row_to > big_df.index.size:
        break

    row_from = row_to
    row_to = row_from + rows_max
    file_n += 1

# %%
def split_toobig(data_directory):
    for filename in os.listdir(data_directory):
        filepath = Path(data_directory+'/'+ filename)
        filesize = os.path.getsize(data_directory+'/'+ filename)
        if filesize > int(5e7):
            csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
            csv_data.columns = [col_name.upper() for col_name in csv_data.columns]
            upper_columns = ['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']
            check = all(item in csv_data.columns for item in upper_columns)
            if check is True:
                clean_data = csv_data[upper_columns]
                new_filename = filepath.stem
                clean_data.to_csv

# %%
data_directory = '/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/rawdata/too_big'
filename = '2017-2019_OU2_PDI_Sediment_PCB_20210924.csv'
filesize = os.path.getsize(data_directory+'/'+ filename)

filepath = Path(data_directory+'/'+ filename)
if filesize > int(5e7):
    csv_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True, low_memory=False)
    csv_data.head()

original_columns = csv_data.columns
# Out:
# Index(['Unnamed: 0', 'FACILITY_ID', 'FACILITY_CODE', 'SYS_LOC_CODE',
#        'LOC_NAME', 'SAMPLE_ID', 'SYS_SAMPLE_CODE', 'SAMPLE_NAME',
#        'SAMPLE_DATE', 'SAMPLEDATE', 'SAMPLETIME', 'SAMPLE_TYPE_CODE',
#        'START_DEPTH', 'END_DEPTH', 'DEPTH_UNIT', 'MATRIX_CODE', 'TASK_CODE',
#        'TASK_CODE_2', 'PARENT_SAMPLE_CODE', 'FIELD_SDG', 'ANALYSIS_LOCATION',
#        'LAB_SAMPLE_ID', 'LAB_MATRIX_CODE', 'LAB_NAME_CODE', 'ANALYTIC_METHOD',
#        'ANALYSIS_DATE', 'COLUMN_NUMBER', 'FRACTION', 'TEST_TYPE',
#        'PREP_METHOD', 'LEACHATE_METHOD', 'LEACHATE_DATE', 'LAB_SDG',
#        'PERCENT_MOISTURE', 'DILUTION_FACTOR', 'TEST_ID', 'CAS_RN',
#        'CHEMICAL_NAME', 'ORGANIC_YN', 'REPORT_RESULT_TEXT',
#        'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT',
#        'REPORT_METHOD_DETECTION_LIMIT', 'REPORT_REPORTING_LIMIT',
#        'REPORT_QUANTITATION_LIMIT', 'REPORTABLE_RESULT', 'DETECT_FLAG',
#        'INTERPRETED_QUALIFIERS', 'VALIDATOR_QUALIFIERS', 'LAB_QUALIFIERS',
#        'QUANTITATION_LIMIT', 'METHOD_DETECTION_LIMIT',
#        'REPORTING_DETECTION_LIMIT', 'DETECTION_LIMIT_UNIT', 'APPROVAL_CODE',
#        'RESULT_TEXT', 'RESULT_NUMERIC', 'RESULT_UNIT', 'RESULT_TYPE_CODE',
#        'LONGITUDE', 'LATITUDE', 'VALIDATED_YN', 'STREAM_CODE', 'STREAM_MILE',
#        'REMARK'],
#       dtype='object')

# %%
rows_max = int(1e5)
number_lines = sum(1 for row in (open(filename)))
header = ['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']
for i in range(1, number_lines, rows_max):
    csv_data = pd.read_csv(filepath, 
        nrows=rows_max,
        skiprows=i,
        parse_dates=True, infer_datetime_format=True, low_memory=False)
    csv_data.columns = [col_name.upper() for col_name in csv_data.columns]
        upper_columns = ['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']
        check = all(item in csv_data.columns for item in upper_columns)
            if check is True:
                clean_data = csv_data[upper_columns]
    csv_data.columns = header
    new_filename = filepath.stem
    if str(i)=='1': 
        csv_number = '1'
    else: 
        csv_number = str(int(i/100000))
    out_csv = new_filename + '_' + csv_number + '.csv'
    csv_data.to_csv(out_csv, index=False, header=True, mode='a', chunksize=rows_max)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 4>()
#       4 for i in range(1, number_lines, rows_max):
#       5     csv_data = pd.read_csv(filepath,
#       6         nrows=rows_max,
#       7         skiprows=i,
#       8         parse_dates=True, infer_datetime_format=True, low_memory=False)
# ----> 9     csv_data.columns = header
#      10     new_filename = filepath.stem
#      11     if str(i)=='1':
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5596, in NDFrame.__setattr__(self, name, value)
#    <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=5593'>5594</a> try:
#    <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=5594'>5595</a>     object.__getattribute__(self, name)
# -> <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=5595'>5596</a>     return object.__setattr__(self, name, value)
#    <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=5596'>5597</a> except AttributeError:
#    <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=5597'>5598</a>     pass
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=766'>767</a> def _set_axis(self, axis: int, labels: Index) -> None:
#     <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=767'>768</a>     labels = ensure_index(labels)
# --> <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=768'>769</a>     self._mgr.set_axis(axis, labels)
#     <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py?line=769'>770</a>     self._clear_item_cache()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=211'>212</a> def set_axis(self, axis: int, new_labels: Index) -> None:
#     <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=212'>213</a>     # Caller is responsible for ensuring we have an Index object.
# --> <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=213'>214</a>     self._validate_set_axis(axis, new_labels)
#     <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py?line=214'>215</a>     self.axes[axis] = new_labels
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=65'>66</a>     pass
#      <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=67'>68</a> elif new_len != old_len:
# ---> <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=68'>69</a>     raise ValueError(
#      <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=69'>70</a>         f"Length mismatch: Expected axis has {old_len} elements, new "
#      <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=70'>71</a>         f"values have {new_len} elements"
#      <a href='file:///Users/laurenkrohn/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=71'>72</a>     )
#
# ValueError: Length mismatch: Expected axis has 66 elements, new values have 13 elements

# %%
for filename in os.listdir(toobig_data_dir):
    filesize = os.path.getsize(toobig_data_dir+'/'+ filename)
    print(filesize)
# Out:
# 163008046
# 6148
# 318898875
# 62861525
# 396388001
# 122218167
# 194735844
# 53968521
# 266428971

# %%
# Operative function to clean too big csvs
toobig_data_dir = '../rawdata/too_big'
for filename in os.listdir(toobig_data_dir):
    filepath = Path(toobig_data_dir+'/'+ filename)
    if filename.endswith('.csv'):
        big_data = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True, low_memory=False)
    big_data.columns = [col_name.upper() for col_name in big_data.columns]
    upper_columns = ['LOC_NAME', 'SAMPLE_DATE', 'TASK_CODE', 'ANALYTIC_METHOD', 'CAS_RN', 'CHEMICAL_NAME', 'REPORT_RESULT_VALUE', 'REPORT_RESULT_UNIT', 'REPORT_RESULT_LIMIT', 'DETECT_FLAG', 'REPORTABLE_RESULT', 'LONGITUDE', 'LATITUDE']
    check = all(item in csv_data.columns for item in upper_columns)
    if check is True:
        big_clean_data = big_data[upper_columns]
    new_filename = filepath.stem
    for i in range(0, len(big_clean_data), int(2e5)):
        csv_number = str(int(i/200000))
        big_clean_data.iloc[i:i+int(2e5)].to_csv(f'{new_filename}_{csv_number}.csv', index=False)

# %%
i=200000
if str(i)=='1': 
    print('1') 
else: 
    print(str(int(i/100000)))
# Out:
# 2

# %%
csv_number = 
    if str(i)=='1': 
        '1'
    else: 
        str(int(i/100000))
# Out:
#   Input In [50]
#     csv_number =
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Get Google Maps coordinates for industrial sites

# %%
filepath = '/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/rawdata/Manufacturing_Sites.csv'
industry_sites = pd.read_csv(filepath, parse_dates=True, infer_datetime_format=True)
industry_sites.head()
# Out:
#   Party Associated with Site     Property at Issue Shorthand  \
# 0    21st Century Fox (TFCF)                   Montrose Site
# 1        21st Century (TFCF)                             NaN
# 2                 3M Company                    CSD Property
# 3                 3M Company  Bayonne Barrel & Drum Property
# 4  Akzo Nobel Coatings, Inc.                    CSD Property
#
#                            Site Address  Latitude  Longitude River Mile (RM)  \
# 0         100/120 Lister Avenue, Newark  40.73932   -74.1345             NaN
# 1                         70 Lister Ave  40.73875   -74.1367             NaN
# 2           704 Doremus Ave., Newark NJ       NaN        NaN           0-0.5
# 3  150-154 Raymond Bouldevard, Neark NJ       NaN        NaN             NaN
# 4           704 Doremus Ave., Newark NJ       NaN        NaN           0-0.5
#
#                 Site Operator Beginning Year of Operations  \
# 0     21st Century Fox (TFCF)                         1939
# 1       Montrose Chemical Co.                         1935
# 2  Central Steel Drum Company                         1951
# 3       Bayonne Barrel & Drum                         1940
# 4  Central Steel Drum Company                         1951
#
#   End Year of Operations                    Description/Notes on Operations  \
# 0                   1972  manufactured many organic chemicals; herbicide...
# 1                   1943                                                NaN
# 2                    NaN  stored, incinerated, reconditioned, and painte...
# 3                   1983  cleaned and reconditioned steel drums which co...
# 4                    NaN  stored, incinerated, reconditioned, and painte...
#
#                                            Main COCs  \
# 0  DDT\nPAHs\nPCBs\ncopper\ndieldrin\ndioxins\nle...
# 1                                                NaN
# 2  DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
# 3          DDT\nPAHs\ncopper\ndioxins\nlead\nmercury
# 4  DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
#
#                    List of COCs Manufactured On-Site  \
# 0  2,4,5-T\n2,4-D\nbis(2-ethylhexyl) phthalate\nb...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  List of COCs Involved in Operations  \
# 0  DDx\nbis(2-ethylhexyl) phthalate\nbutyl phthal...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#               List of COCs that are by-product/waste  \
# 0                      copper\ndioxins\nfurans\nlead
# 1                                                NaN
# 2                                                NaN
# 3  PAHs\nPCBs\ncopper\ndioxins\nlead\nmercury\nme...
# 4                                                NaN
#
#                On-site Soil/Groundwater Contaminants  \
# 0  DDx\nchlorinated benzenes\ndichlorophenol\ndie...
# 1  chlorobenzene\ndichlorobenzene\ndioxins\nfuran...
# 2  DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
# 3                                                NaN
# 4  DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
#
#     Party Responsible for Remediation  Beginning Year of Remediation  \
# 0             21st Century Fox (TFCF)                            NaN
# 1                                 NaN                            NaN
# 2                      CSD defendants                            NaN
# 3  Bayonne Barrel and Drum Defendants                            NaN
# 4                      CSD defendants                            NaN
#
#    End Year of Remediation List of COCs found on-site during Remediation
# 0                      NaN                                           NaN
# 1                      NaN                                           NaN
# 2                      NaN                                           NaN
# 3                      NaN                                           NaN
# 4                      NaN                                           NaN

# %%
industry_sites = industry_sites.rename(columns={'Site Address':'Site_Address'})
industry_sites.head()
# Out:
#   Party Associated with Site     Property at Issue Shorthand  \
# 0    21st Century Fox (TFCF)                   Montrose Site
# 1        21st Century (TFCF)                             NaN
# 2                 3M Company                    CSD Property
# 3                 3M Company  Bayonne Barrel & Drum Property
# 4  Akzo Nobel Coatings, Inc.                    CSD Property
#
#                            Site_Address  Latitude  Longitude River Mile (RM)  \
# 0         100/120 Lister Avenue, Newark  40.73932   -74.1345             NaN
# 1                         70 Lister Ave  40.73875   -74.1367             NaN
# 2           704 Doremus Ave., Newark NJ       NaN        NaN           0-0.5
# 3  150-154 Raymond Bouldevard, Neark NJ       NaN        NaN             NaN
# 4           704 Doremus Ave., Newark NJ       NaN        NaN           0-0.5
#
#                 Site Operator Beginning Year of Operations  \
# 0     21st Century Fox (TFCF)                         1939
# 1       Montrose Chemical Co.                         1935
# 2  Central Steel Drum Company                         1951
# 3       Bayonne Barrel & Drum                         1940
# 4  Central Steel Drum Company                         1951
#
#   End Year of Operations                    Description/Notes on Operations  \
# 0                   1972  manufactured many organic chemicals; herbicide...
# 1                   1943                                                NaN
# 2                    NaN  stored, incinerated, reconditioned, and painte...
# 3                   1983  cleaned and reconditioned steel drums which co...
# 4                    NaN  stored, incinerated, reconditioned, and painte...
#
#                                            Main COCs  \
# 0  DDT\nPAHs\nPCBs\ncopper\ndieldrin\ndioxins\nle...
# 1                                                NaN
# 2  DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
# 3          DDT\nPAHs\ncopper\ndioxins\nlead\nmercury
# 4  DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
#
#                    List of COCs Manufactured On-Site  \
# 0  2,4,5-T\n2,4-D\nbis(2-ethylhexyl) phthalate\nb...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  List of COCs Involved in Operations  \
# 0  DDx\nbis(2-ethylhexyl) phthalate\nbutyl phthal...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#               List of COCs that are by-product/waste  \
# 0                      copper\ndioxins\nfurans\nlead
# 1                                                NaN
# 2                                                NaN
# 3  PAHs\nPCBs\ncopper\ndioxins\nlead\nmercury\nme...
# 4                                                NaN
#
#                On-site Soil/Groundwater Contaminants  \
# 0  DDx\nchlorinated benzenes\ndichlorophenol\ndie...
# 1  chlorobenzene\ndichlorobenzene\ndioxins\nfuran...
# 2  DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
# 3                                                NaN
# 4  DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
#
#     Party Responsible for Remediation  Beginning Year of Remediation  \
# 0             21st Century Fox (TFCF)                            NaN
# 1                                 NaN                            NaN
# 2                      CSD defendants                            NaN
# 3  Bayonne Barrel and Drum Defendants                            NaN
# 4                      CSD defendants                            NaN
#
#    End Year of Remediation List of COCs found on-site during Remediation
# 0                      NaN                                           NaN
# 1                      NaN                                           NaN
# 2                      NaN                                           NaN
# 3                      NaN                                           NaN
# 4                      NaN                                           NaN

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json?"

# %%
def getLocation(row):
     params = {
         "key": "google_key",
         "address": row.Site_Address
     }
     try:  

          #address = params[Site_Address]
          response = requests.get(base_url, params = params).json()
               #print(response.keys())
          if response ["status"] == "OK":
               geometry = response["results"][0]["geometry"]
               latitude = geometry["location"]["lat"]
               longitude = geometry["location"]["lng"]
          return (latitude, longitude)
     except: 
          return (0,0)


#Site_Address = row.Site_Address


industry_sites[["Latitude", "Longitude"]] = industry_sites.apply(getLocation, result_type='expand', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/cleandata/lauren_data_cleaning.ipynb Cell 31' in <cell line: 23>()
#      <a href='vscode-notebook-cell:/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/cleandata/lauren_data_cleaning.ipynb#ch0000030?line=16'>17</a>           return (0,0)
#      <a href='vscode-notebook-cell:/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/cleandata/lauren_data_cleaning.ipynb#ch0000030?line=19'>20</a> #Site_Address = row.Site_Address
# ---> <a href='vscode-notebook-cell:/Users/laurenkrohn/Documents/GitHub-Local/project_1/environmental-contamination/data/cleandata/lauren_data_cleaning.ipynb#ch0000030?line=22'>23</a> industry_sites[["Latitude", "Longitude"]] = industry_sites.apply(getLocation, result_type='expand', axis=1)
#
# NameError: name 'industry_sites' is not defined

# %%
industry_sites.tail(20)
industry_sites.dropna(subset=['Site_Address'], inplace=True)

# %%
industry_sites.head()
# Out:
#   Party Associated with Site     Property at Issue Shorthand  \
# 0    21st Century Fox (TFCF)                   Montrose Site
# 1        21st Century (TFCF)                             NaN
# 2                 3M Company                    CSD Property
# 3                 3M Company  Bayonne Barrel & Drum Property
# 4  Akzo Nobel Coatings, Inc.                    CSD Property
#
#                            Site_Address   Latitude  Longitude River Mile (RM)  \
# 0         100/120 Lister Avenue, Newark  40.738889 -74.133710             NaN
# 1                         70 Lister Ave  40.738656 -74.136551             NaN
# 2           704 Doremus Ave., Newark NJ  40.708879 -74.131816           0-0.5
# 3  150-154 Raymond Bouldevard, Neark NJ  40.734361 -74.126863             NaN
# 4           704 Doremus Ave., Newark NJ  40.708879 -74.131816           0-0.5
#
#                 Site Operator Beginning Year of Operations  \
# 0     21st Century Fox (TFCF)                         1939
# 1       Montrose Chemical Co.                         1935
# 2  Central Steel Drum Company                         1951
# 3       Bayonne Barrel & Drum                         1940
# 4  Central Steel Drum Company                         1951
#
#   End Year of Operations                    Description/Notes on Operations  \
# 0                   1972  manufactured many organic chemicals; herbicide...
# 1                   1943                                                NaN
# 2                    NaN  stored, incinerated, reconditioned, and painte...
# 3                   1983  cleaned and reconditioned steel drums which co...
# 4                    NaN  stored, incinerated, reconditioned, and painte...
#
#                                            Main COCs  \
# 0  DDT\nPAHs\nPCBs\ncopper\ndieldrin\ndioxins\nle...
# 1                                                NaN
# 2  DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
# 3          DDT\nPAHs\ncopper\ndioxins\nlead\nmercury
# 4  DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
#
#                    List of COCs Manufactured On-Site  \
# 0  2,4,5-T\n2,4-D\nbis(2-ethylhexyl) phthalate\nb...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  List of COCs Involved in Operations  \
# 0  DDx\nbis(2-ethylhexyl) phthalate\nbutyl phthal...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#               List of COCs that are by-product/waste  \
# 0                      copper\ndioxins\nfurans\nlead
# 1                                                NaN
# 2                                                NaN
# 3  PAHs\nPCBs\ncopper\ndioxins\nlead\nmercury\nme...
# 4                                                NaN
#
#                On-site Soil/Groundwater Contaminants  \
# 0  DDx\nchlorinated benzenes\ndichlorophenol\ndie...
# 1  chlorobenzene\ndichlorobenzene\ndioxins\nfuran...
# 2  DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
# 3                                                NaN
# 4  DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
#
#     Party Responsible for Remediation  Beginning Year of Remediation  \
# 0             21st Century Fox (TFCF)                            NaN
# 1                                 NaN                            NaN
# 2                      CSD defendants                            NaN
# 3  Bayonne Barrel and Drum Defendants                            NaN
# 4                      CSD defendants                            NaN
#
#    End Year of Remediation List of COCs found on-site during Remediation
# 0                      NaN                                           NaN
# 1                      NaN                                           NaN
# 2                      NaN                                           NaN
# 3                      NaN                                           NaN
# 4                      NaN                                           NaN

# %%
industry_sites.tail(20)
# Out:
#                  Party Associated with Site     Property at Issue Shorthand  \
# 127                               STWB Inc.                             NaN
# 128                Sun Chemical Corporation                             NaN
# 129    Tate & Lyle Ingredients Americas LLC                             NaN
# 130    Tate & Lyle Ingredients Americas LLC                             NaN
# 131                             Teval Corp.                             NaN
# 132                            Textron Inc.                             NaN
# 133                           Textron, Inc.                             NaN
# 134          The Hartz Mountain Corporation                             NaN
# 135                  The Newark Group, Inc.                             NaN
# 136                     The Okonite Company                             NaN
# 137            The Sherwin-Williams Company           Sherwin Williams Site
# 138            The Sherwin-Williams Company                    CSD Property
# 139                  The two Sunoco Parties                             NaN
# 140                     Tiffany and Company                             NaN
# 141         United States Steel Corporation                             NaN
# 142  ViacomCBS Inc. (f/k/a CBS Corporation)                             NaN
# 143      Schiffenhaus Packaging Corporation                             NaN
# 144                  Wiggins Plastics, Inc.                             NaN
# 145                            Zeneca, Inc.  Bayonne Barrel & Drum Property
# 146                       ISP Chemicals LLC                ISP - Belleville
#
#                                           Site_Address   Latitude  Longitude  \
# 127                     104-112 Lister Ave., Newark NJ  40.739037 -74.134295
# 128                      185 Foundry Street, Newark NJ  40.728463 -74.132575
# 129                       320 Schuyler Ave., Kearny NJ  40.759721 -74.142851
# 130                          100 Third Ave., Kearny NJ  40.758442 -74.140910
# 131          900-1000 South Fourth Street, Harrison NJ  40.751911 -74.157567
# 132                     681 Main Street, Belleville NJ  40.804307 -74.141031
# 133                        400 Doremus Ave., Newark NJ  40.719338 -74.124740
# 134  600 and 700 Blocks, South 4th Street, Harrison NJ  40.751911 -74.157567
# 135                     17 Blanchard Street, Newark NJ  40.735490 -74.128615
# 136  Block 1076, Canal and Jefferson Streets, Passa...  40.863587 -74.122086
# 137                  40, 60, 62-70 Lister Ave., Newark  40.739041 -74.138310
# 138                        704 Doremus Ave., Newark NJ  40.708879 -74.131816
# 139                        436 Doremus Ave., Newark NJ  40.717663 -74.124730
# 140                       820 Highland Ave., Newark NJ  40.784297 -74.166269
# 141                        100 Central Ave., Kearny NJ  40.731314 -74.113776
# 142                        95 Orange Street, Newark NJ  40.746207 -74.171436
# 143                   2013 McCarter Highway, Newark NJ  40.775687 -74.153517
# 144                     180 Kingsland Road, Clifton NJ  40.827300 -74.142117
# 145               150-154 Raymond Boulevard, Newark NJ  40.734361 -74.126863
# 146                   11 William Street, Belleville NJ  40.783656 -74.150057
#
#     River Mile (RM)                         Site Operator  \
# 127             NaN                             STWB Inc.
# 128             NaN              Sun Chemical Corporation
# 129             NaN  Tate & Lyle Ingredients Americas LLC
# 130             NaN  Tate & Lyle Ingredients Americas LLC
# 131             NaN                     Teval Corporation
# 132             NaN         Federal Leather Company, Inc.
# 133             NaN                         Textron, Inc.
# 134             NaN        The Hartz Mountain Corporation
# 135             NaN                The Newark Group, Inc.
# 136             NaN             The Okonite Company, Inc.
# 137             NaN          The Sherwin-Williams Company
# 138           0-0.5            Central Steel Drum Company
# 139           0-0.5                The two Sunoco parties
# 140             NaN                   Tiffany and Company
# 141             NaN       United States Steel Corporation
# 142             NaN                       CBS Corporation
# 143             NaN    Schiffenhaus Packaging Corporation
# 144             NaN                Wiggins Plastics, Inc.
# 145             NaN                 Bayonne Barrel & Drum
# 146             NaN                     ISP Chemicals LLC
#
#     Beginning Year of Operations End Year of Operations  \
# 127                         1986                    NaN
# 128                    1986/1987                   2003
# 129                         1966        1975 (at least)
# 130                          NaN                   1978
# 131                         1947                    NaN
# 132                         1956                   1968
# 133                         1978                    NaN
# 134                         1970        1993 (at least)
# 135                   late 1890s                    NaN
# 136                at least 1973                    NaN
# 137                         1902                   1999
# 138                         1951                    NaN
# 139                         1916                present
# 140                         1897                   1985
# 141                         1917                   1948
# 142                         1893                   1983
# 143                         1895                present
# 144                         1955                present
# 145                         1940                   1983
# 146                         1943                present
#
#                        Description/Notes on Operations  \
# 127  produced phthalocyanine colors, transoxides fo...
# 128  manufactured organic pigments for automotive p...
# 129  manufactured polymers, rubber-based adhesives,...
# 130  manufactured polymers, rubber-based adhesives,...
# 131               operated a pipe fabrication facility
# 132  manufactured leather, artificial leather, and ...
# 133                  manufactured chemicals and resins
# 134  manufactured, assembled, warehoused, and distr...
# 135  manufactured recycled paperboard into plain, l...
# 136  manufactured insulated electrical wires, cable...
# 137  manufactured paints and related products and D...
# 138  stored, incinerated, reconditioned, and painte...
# 139  shipped, stored, and distributed petroleum pro...
# 140  produced sterling silver and manufactured flat...
# 141          built and repaired merchant and war ships
# 142  manufactured relay instrument and electrical e...
# 143                  manufactured linerboard and fiber
# 144  manufactured thermoset and thermoplastic compo...
# 145  cleaned and reconditioned steel drums sent to ...
# 146  manufacured ultraviolet absorbers, emulsifiers...
#
#                                              Main COCs  \
# 127                  PAHs\nPCBs\ncopper\nlead\nmercury
# 128                  PAHs\nPCBs\ncopper\nlead\nmercury
# 129                              copper\nlead\nmercury
# 130                              copper\nlead\nmercury
# 131                  PAHs\nPCBs\ncopper\nlead\nmercury
# 132                              PAHs\ncopper\nmercury
# 133                  PAHs\nPCBs\ncopper\nlead\nmercury
# 134                  PAHs\nPCBs\ncopper\nlead\nmercury
# 135  PCBs\ncopper\ndioxin-associated compounds\nlea...
# 136  PAHs\nPCBs\ncopper\ndioxin-associated compound...
# 137   DDT\nPAHs\nPCBs\ncopper\ndieldrin\nlead\nmercury
# 138  DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
# 139                           PAHs\nPCBs\ncopper\nlead
# 140                        PAHs\ncopper\nlead\nmercury
# 141                        PAHs\ncopper\nlead\nmercury
# 142                              copper\nlead\nmercury
# 143                                                NaN
# 144  PAHs\nPCBs\ncopper\ndioxin-associated compound...
# 145    DDT\nPAHs\nPCBs\ncopper\ndioxins\nlead\nmercury
# 146                       PAHs\nPCBs\ndioxins\nmercury
#
#     List of COCs Manufactured On-Site  \
# 127                               NaN
# 128                               NaN
# 129                               NaN
# 130                               NaN
# 131                               NaN
# 132                               NaN
# 133      alkyd resin\npolyester resin
# 134                               NaN
# 135                               NaN
# 136                               NaN
# 137                               NaN
# 138                               NaN
# 139                               NaN
# 140                               NaN
# 141                               NaN
# 142                               NaN
# 143                               NaN
# 144                               NaN
# 145                               NaN
# 146                               NaN
#
#                    List of COCs Involved in Operations  \
# 127  PCBs\nchlorinated naphthalenes\nchlorine\ncopp...
# 128  PCBs\nacetic acid\narsenic\nbis(2-ethylhexyl) ...
# 129  chromium\ncopper\nethyl acrylate\nlead\nmercur...
# 130  chromium\ncopper\nethyl acrylate\nlead\nmercur...
# 131               copper\nlead\nmercury\nsulfuric acid
# 132                                                NaN
# 133                  PAHs\ndioxin-associated compounds
# 134  acetylene\nbattery acid\ndimethyl ether\nfungi...
# 135                        PCBs\ncopper\nlead\nmercury
# 136                                  trichloroethylene
# 137                                                NaN
# 138                                                NaN
# 139  PAHs\nfuel oil\noil products\noil/water separa...
# 140      hydrofluoric acid\nnitric acid\nsulfuric acid
# 141                        PAHs\ncopper\nlead\nmercury
# 142         Pyranol A\ncopper\ncutting-oil waste\nlead
# 143                        PAHs\ncopper\nlead\nmercury
# 144  PAHs\nPCBs\nbenzene\ncopper\niron\npetroleum h...
# 145                                                NaN
# 146  acetone\nchloroform\nformaldehyde\nfuel oil\nm...
#
#                 List of COCs that are by-product/waste  \
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134  chlorides\ngrease\nlead\nmercury\noil\npestici...
# 135                     arsenic\ncopper\nlead\nmercury
# 136                                               PAHs
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142   caustic soda\ncopper\ngrease\nlead\nmercury\noil
# 143                        PAHs\ncopper\nlead\nmercury
# 144                               hazardous substances
# 145                                                NaN
# 146                                                NaN
#
#                  On-site Soil/Groundwater Contaminants  \
# 127  PAHs\nPCBs\ncopper\ndichlorobenzene\nhexachlor...
# 128  PCBs\nbase neutrals\ncopper\nlead\nmercury\not...
# 129                                                NaN
# 130                                                NaN
# 131  PAHs\nPCBs\ncopper\ndieldrin\ndioxin-associate...
# 132                                                NaN
# 133                  PAHs\nPCBs\ncopper\nlead\nmercury
# 134                         PCBs\ncopper\nlead\nnickel
# 135                                                NaN
# 136  copper\ndioxin-associated compounds\nlead\nmer...
# 137                                                NaN
# 138  DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
# 139  PAHs\nPCBs\niron\nlead\nvolatile organic compo...
# 140                        PAHs\ncopper\nlead\nmercury
# 141  PAHs\nchromium\nchrysene\ncopper\nlead\nmercur...
# 142  PAHs\nPCBs\ncopper\ndieldrin compounds\ndioxin...
# 143                                                NaN
# 144  arsenic\nchlorobenzene\nchloroform\ncopper\nle...
# 145  PAHs\nPCBs\ncopper\ndioxins\nlead\nmercury\not...
# 146  PCBs\nPHCs\nbenzene\ndi-n-butyl phthalate\nmer...
#
#                      Party Responsible for Remediation  \
# 127                                          STWB Inc.
# 128                           Sun Chemical Corporation
# 129               Tate & Lyle Ingredients Americas LLC
# 130               Tate & Lyle Ingredients Americas LLC
# 131                                  Teval Corporation
# 132                                      Textron, Inc.
# 133                                      Textron, Inc.
# 134                     The Hartz Mountain Corporation
# 135                             The Newark Group, Inc.
# 136                                                NaN
# 137                                                NaN
# 138                                     CSD defendants
# 139  Sunoco (R&M), LLC\nSunoco Partners Marketing &...
# 140                                Tiffany and Company
# 141  RTC Properties, Inc.\nUnited States Steel Corp...
# 142                                                NaN
# 143                                                NaN
# 144                             Wiggins Plastics, Inc.
# 145                          Bayonne Barrel Defendants
# 146                                                NaN
#
#      Beginning Year of Remediation  End Year of Remediation  \
# 127                            NaN                      NaN
# 128                            NaN                      NaN
# 129                            NaN                      NaN
# 130                            NaN                      NaN
# 131                            NaN                      NaN
# 132                            NaN                      NaN
# 133                            NaN                      NaN
# 134                            NaN                      NaN
# 135                            NaN                      NaN
# 136                            NaN                      NaN
# 137                            NaN                      NaN
# 138                            NaN                      NaN
# 139                         1993.0                      NaN
# 140                            NaN                      NaN
# 141                            NaN                      NaN
# 142                            NaN                      NaN
# 143                            NaN                      NaN
# 144                            NaN                      NaN
# 145                            NaN                      NaN
# 146                            NaN                      NaN
#
#     List of COCs found on-site during Remediation
# 127                                           NaN
# 128                                           NaN
# 129                                           NaN
# 130                                           NaN
# 131                                           NaN
# 132                                           NaN
# 133                                           NaN
# 134                                           NaN
# 135                                           NaN
# 136                                           NaN
# 137                                           NaN
# 138                                           NaN
# 139                                           NaN
# 140                                           NaN
# 141                                           NaN
# 142                                           NaN
# 143                                           NaN
# 144                                           NaN
# 145                                           NaN
# 146                                           NaN

# %%
industry_sites.to_csv('industry_coordinates.csv')
industry_sites.to_excel('industry_coordinates.xlsx')

# %%
industry_sites[["Latitude", "Longitude"]] 
df.head()
# Out:
# 0    (40.7388893, -74.1337099)
# 1    (40.7386556, -74.1365509)
# 2    (40.7088793, -74.1318163)
# Name: Site_Address, dtype: object

# %%
address = "704 Doremus Ave., Newark NJ"
getLocation(address)
# Out:
# (40.7088793, -74.1318163)

# %%
industry_sites
# Out:
#     Party Associated with Site     Property at Issue Shorthand  \
# 0      21st Century Fox (TFCF)                   Montrose Site
# 1          21st Century (TFCF)                             NaN
# 2                   3M Company                    CSD Property
# 3                   3M Company  Bayonne Barrel & Drum Property
# 4    Akzo Nobel Coatings, Inc.                    CSD Property
# ..                         ...                             ...
# 162                        NaN                             NaN
# 163                        NaN                             NaN
# 164                        NaN                             NaN
# 165                        NaN                             NaN
# 166                        NaN                             NaN
#
#                              Site Address  Latitude  Longitude  \
# 0           100/120 Lister Avenue, Newark  40.73932   -74.1345
# 1                           70 Lister Ave  40.73875   -74.1367
# 2             704 Doremus Ave., Newark NJ       NaN        NaN
# 3    150-154 Raymond Bouldevard, Neark NJ       NaN        NaN
# 4             704 Doremus Ave., Newark NJ       NaN        NaN
# ..                                    ...       ...        ...
# 162                                   NaN       NaN        NaN
# 163                                   NaN       NaN        NaN
# 164                                   NaN       NaN        NaN
# 165                                   NaN       NaN        NaN
# 166                                   NaN       NaN        NaN
#
#     River Mile (RM)               Site Operator Beginning Year of Operations  \
# 0               NaN     21st Century Fox (TFCF)                         1939
# 1               NaN       Montrose Chemical Co.                         1935
# 2             0-0.5  Central Steel Drum Company                         1951
# 3               NaN       Bayonne Barrel & Drum                         1940
# 4             0-0.5  Central Steel Drum Company                         1951
# ..              ...                         ...                          ...
# 162             NaN                         NaN                          NaN
# 163             NaN                         NaN                          NaN
# 164             NaN                         NaN                          NaN
# 165             NaN                         NaN                          NaN
# 166             NaN                         NaN                          NaN
#
#     End Year of Operations                    Description/Notes on Operations  \
# 0                     1972  manufactured many organic chemicals; herbicide...
# 1                     1943                                                NaN
# 2                      NaN  stored, incinerated, reconditioned, and painte...
# 3                     1983  cleaned and reconditioned steel drums which co...
# 4                      NaN  stored, incinerated, reconditioned, and painte...
# ..                     ...                                                ...
# 162                    NaN                                                NaN
# 163                    NaN                                                NaN
# 164                    NaN                                                NaN
# 165                    NaN                                                NaN
# 166                    NaN                                                NaN
#
#                                              Main COCs  \
# 0    DDT\nPAHs\nPCBs\ncopper\ndieldrin\ndioxins\nle...
# 1                                                  NaN
# 2    DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
# 3            DDT\nPAHs\ncopper\ndioxins\nlead\nmercury
# 4    DDT\nPAHs\ncopper\ndieldrin\ndioxins\nlead\nme...
# ..                                                 ...
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
#
#                      List of COCs Manufactured On-Site  \
# 0    2,4,5-T\n2,4-D\nbis(2-ethylhexyl) phthalate\nb...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
#
#                    List of COCs Involved in Operations  \
# 0    DDx\nbis(2-ethylhexyl) phthalate\nbutyl phthal...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
#
#                 List of COCs that are by-product/waste  \
# 0                        copper\ndioxins\nfurans\nlead
# 1                                                  NaN
# 2                                                  NaN
# 3    PAHs\nPCBs\ncopper\ndioxins\nlead\nmercury\nme...
# 4                                                  NaN
# ..                                                 ...
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
#
#                  On-site Soil/Groundwater Contaminants  \
# 0    DDx\nchlorinated benzenes\ndichlorophenol\ndie...
# 1    chlorobenzene\ndichlorobenzene\ndioxins\nfuran...
# 2    DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
# 3                                                  NaN
# 4    DDT\nHMW PAHs\nLMW PAH\nPAHs\nPCBs\ncopper\ndi...
# ..                                                 ...
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
#
#       Party Responsible for Remediation  Beginning Year of Remediation  \
# 0               21st Century Fox (TFCF)                            NaN
# 1                                   NaN                            NaN
# 2                        CSD defendants                            NaN
# 3    Bayonne Barrel and Drum Defendants                            NaN
# 4                        CSD defendants                            NaN
# ..                                  ...                            ...
# 162                                 NaN                            NaN
# 163                                 NaN                            NaN
# 164                                 NaN                            NaN
# 165                                 NaN                            NaN
# 166                                 NaN                            NaN
#
#      End Year of Remediation List of COCs found on-site during Remediation
# 0                        NaN                                           NaN
# 1                        NaN                                           NaN
# 2                        NaN                                           NaN
# 3                        NaN                                           NaN
# 4                        NaN                                           NaN
# ..                       ...                                           ...
# 162                      NaN                                           NaN
# 163                      NaN                                           NaN
# 164                      NaN                                           NaN
# 165                      NaN                                           NaN
# 166                      NaN                                           NaN
#
# [167 rows x 19 columns]

# %%
address = "704 Doremus Ave., Newark NJ"
#Key-value
params = {
     "key" : "google_key",
     "address": address
}
base_url = "https://maps.googleapis.com/maps/api/geocode/json?"

# %%
response = requests.get(base_url, params = params).json()
response.keys()
if response ["status"] == "OK":
     geometry = response["results"][0]["geometry"]
     latitude = geometry["location"]["lat"]
     longitude = geometry["location"]["lng"]
print(longitude)
# Out:
# -74.1318163

# %%
def industry_location(address)
