# %%
import pandas as pd
from pathlib import Path
import numpy as np
import panel as pn
pn.extension('plotly')
import plotly.express as px
import hvplot.pandas
import os
from libs.p1_library import chemical_filter
from libs.p1_library import chemical_to_moles
from datetime import datetime

# %%
file_path = '../data/cleandata'
chemical_list = ["2,3,7,8-Tetrachlorodibenzo-p-dioxin","Dieldrin","Hexachlorobiphenyl; 3,3',4,4',5,5'- (PCB 169)","Pentachlorobiphenyl; 3,3',4,4',5- (PCB 126)","Mercury","Lead","Cyanide"]

chemical_df = chemical_filter(file_path,chemical_list)

# %%
chemical_df
# Out:
#                SAMPLE_DATE  ...      LOC_NAME
# 54     2017-10-10 08:00:00  ...           NaN
# 130    2017-10-19 14:50:00  ...           NaN
# 222    2017-10-19 14:50:00  ...           NaN
# 298    2017-10-19 14:50:00  ...           NaN
# 390    2017-10-19 14:50:00  ...           NaN
# ...                    ...  ...           ...
# 15876  2019-07-09 11:00:00  ...   LPR-0403-01
# 15881  2019-07-10 10:45:00  ...   LPR-0430-07
# 15884  2019-07-09 16:10:00  ...  LPR-0752-01R
# 15889  2019-07-09 14:15:00  ...  LPR-0790-03R
# 15893  2019-07-10 00:00:00  ...   LPR-0430-07
#
# [76488 rows x 13 columns]

# %%
chemical_converted = chemical_to_moles(chemical_df)
chemical_converted
# Out:
#                SAMPLE_DATE  ... VALUE_MUMOL_PER_GRAM
# 54     2017-10-10 08:00:00  ...         1.220611e-07
# 130    2017-10-19 14:50:00  ...         3.292232e-07
# 222    2017-10-19 14:50:00  ...         6.180700e-07
# 298    2017-10-19 14:50:00  ...         1.702022e-06
# 390    2017-10-19 14:50:00  ...         3.071715e-07
# ...                    ...  ...                  ...
# 15876  2019-07-09 11:00:00  ...         1.930502e+00
# 15881  2019-07-10 10:45:00  ...         1.785714e+00
# 15884  2019-07-09 16:10:00  ...         5.308880e-02
# 15889  2019-07-09 14:15:00  ...         2.461390e-01
# 15893  2019-07-10 00:00:00  ...         2.123552e+00
#
# [76217 rows x 15 columns]

# %%
#lead_mercury_cyanide_list = ['Lead','Mercury','Cyanide']
#lead_mercury_cyanide_df = chemical_df[chemical_df['CHEMICAL_NAME'].isin(lead_mercury_cyanide_list)]
#lead_mercury_cyanide_df

# %%
#chemical_df.REPORT_RESULT_UNIT.unique()
# Out:
# array(['pg/g', 'pg/sample', 'ppt', 'ppb', 'ppm', 'ug/kg', nan, 'UMOLES/G',
#        'ng/g', 'umol/g', 'mg/kg', 'ng/kg', 'pg', 'pg/l', 'ng/l', 'ug/l',
#        'mg/l'], dtype=object)
