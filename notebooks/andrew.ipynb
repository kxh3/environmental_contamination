# %%
import pandas as pd
from pathlib import Path
import numpy as np
import os
from libs.p1_library import chemical_filter
from datetime import datetime

# %%
file_path = '../data/cleandata'
chemical_list = ["2,3,7,8-Tetrachlorodibenzo-p-dioxin","Dieldrin","Hexachlorobiphenyl; 3,3',4,4',5,5'- (PCB 169)","Pentachlorobiphenyl; 3,3',4,4',5- (PCB 126)","Mercury","Lead","Cyanide"]

chemical_df = chemical_filter(file_path,chemical_list)

# %%
chemical_df
# Out:
#                LOC_NAME          SAMPLE_DATE  \
# 0      Hackensack River            7/23/1985
# 244    Hackensack River            7/30/1985
# 488       Kill Van Kull            8/20/1981
# 732          Newark Bay            8/21/1985
# 976          Newark Bay            4/26/1985
# ...                 ...                  ...
# 15876       LPR-0403-01  2019-07-09 11:00:00
# 15881       LPR-0430-07  2019-07-10 10:45:00
# 15884      LPR-0752-01R  2019-07-09 16:10:00
# 15889      LPR-0790-03R  2019-07-09 14:15:00
# 15893       LPR-0430-07  2019-07-10 00:00:00
#
#                                     TASK_CODE ANALYTIC_METHOD     CAS_RN  \
# 0         1981-2014 RPI(Bopp) SED/ SUS Matter   E1613B MLA017  1746-01-6
# 244       1981-2014 RPI(Bopp) SED/ SUS Matter   E1613B MLA017  1746-01-6
# 488       1981-2014 RPI(Bopp) SED/ SUS Matter   E1613B MLA017  1746-01-6
# 732       1981-2014 RPI(Bopp) SED/ SUS Matter   E1613B MLA017  1746-01-6
# 976       1981-2014 RPI(Bopp) SED/ SUS Matter   E1613B MLA017  1746-01-6
# ...                                       ...             ...        ...
# 15876  2019 OU2 PDI Porewater Passive Sampler          SW6010  7439-92-1
# 15881  2019 OU2 PDI Porewater Passive Sampler          SW6010  7439-92-1
# 15884  2019 OU2 PDI Porewater Passive Sampler          SW6010  7439-92-1
# 15889  2019 OU2 PDI Porewater Passive Sampler          SW6010  7439-92-1
# 15893  2019 OU2 PDI Porewater Passive Sampler          SW6010  7439-92-1
#
#                              CHEMICAL_NAME  REPORT_RESULT_VALUE  \
# 0      2,3,7,8-Tetrachlorodibenzo-p-dioxin                 48.3
# 244    2,3,7,8-Tetrachlorodibenzo-p-dioxin                229.0
# 488    2,3,7,8-Tetrachlorodibenzo-p-dioxin                 55.4
# 732    2,3,7,8-Tetrachlorodibenzo-p-dioxin                108.0
# 976    2,3,7,8-Tetrachlorodibenzo-p-dioxin                113.0
# ...                                    ...                  ...
# 15876                                 Lead                400.0
# 15881                                 Lead                370.0
# 15884                                 Lead                 11.0
# 15889                                 Lead                 51.0
# 15893                                 Lead                440.0
#
#       REPORT_RESULT_UNIT  REPORT_RESULT_LIMIT DETECT_FLAG REPORTABLE_RESULT  \
# 0                   pg/g                0.485           Y               Yes
# 244                 pg/g                0.481           Y               Yes
# 488                 pg/g                0.495           Y               Yes
# 732                 pg/g                0.481           Y               Yes
# 976            pg/sample                0.671           Y               Yes
# ...                  ...                  ...         ...               ...
# 15876              mg/kg                0.990           Y               Yes
# 15881              mg/kg                1.100           Y               Yes
# 15884              mg/kg                0.730           Y               Yes
# 15889              mg/kg                0.640           Y               Yes
# 15893              mg/kg                1.200           Y               Yes
#
#        LONGITUDE   LATITUDE
# 0     -74.039502  40.879778
# 244   -74.069464  40.798054
# 488   -74.098822  40.648703
# 732   -74.139111  40.671200
# 976   -74.139111  40.671200
# ...          ...        ...
# 15876 -74.145593  40.735957
# 15881 -74.149512  40.734412
# 15884 -74.155944  40.770182
# 15889 -74.152242  40.774933
# 15893 -74.149512  40.734412
#
# [7766 rows x 13 columns]

# %%
#contaminants_df = pd.read_csv('../notebooks/chemical_filter.csv')
#contaminants_df.drop(columns='Unnamed: 0',inplace=True)
#contaminants_df

# %%
chemical_list = ["2,3,7,8-Tetrachlorodibenzo-p-dioxin","Dieldrin","Hexachlorobiphenyl; 3,3',4,4',5,5'- (PCB 169)","Pentachlorobiphenyl; 3,3',4,4',5- (PCB 126)","Mercury","Lead","Cyanide"]
file_path = '../data/cleandata'
chemical_filtered
